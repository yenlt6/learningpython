# %% [markdown]
# Viết chương trình in ra thời gian đếm ngược đến XMas 2021 sau mỗi 10s

# %%
import time
from datetime import datetime

while True:
    time.sleep(10)
    XMAS_DATE = datetime(year=2021, month=12, day=24)
    countdown = XMAS_DATE - datetime.now()
    print(f"Countdown to Xmas 2021: {countdown}")
    if countdown == 0:
        break

# %%
# Viết chương trình trả ra từ điển với key là các số trong list, value là số lần xuất hiện của số trong list
from collections import Counter
my_list = [10, 21, 21, 40, 40, 52, 52, 1, 1, 2, 2, 2, 2, 11, 11, 11, 11, 25, 24, 24, 60, 40]
c = Counter(my_list)
c

# %% [markdown]
# ### Unique value Dictionary:
# Cho một list gồm 1 hoặc nhiều từ điển (Dictionary). Viết hàm để trả ra tập hợp tất cả các giá trị (values) duy nhất trong tất cả danh sách các từ điển trên.
#
# [VD1]: Trường hợp dưới đây danh sách đầu vào có 1 từ điển map tên người vào tuổi của họ. Trả ra set các tuổi duy nhất.
#
#     unique_value_dict([dict(Trang=38, Thu=38, Ngoc=27, Thanh=26, Yen=25, Hang=22, Thuy=22)]) == {22, 25, 26, 27, 38}
#
# [VD2]: Trường hợp dưới đây danh sách đầu vào có 7 dicts, mỗi dict chỉ có 1 cặp key-values. 5 giá trị trả về là duy nhất.
#
#     unique_value_dict([{"V":"S001"}, {"V": "S002"}, {"VI": "S001"}, {"VI": "S005"}, {"VII":"S005"}, {"V":"S009"},{"VIII":"S007"}]) == {'S009', 'S007', 'S002', 'S001', 'S005'}

# %%
my_dict = [dict(Trang=38, Thu=38, Ngoc=27, Thanh=26, Yen=25, Hang=22, Thuy=22)]
def unique_value_dict(my_dict):
    return set( val for dic in my_dict for val in dic.values())

unique_value_dict(my_dict)

# %% [markdown]
# ### Print Star
#
# Hãy viết chương trình in ra các hình sau (dùng ký tự '*' và ký tự space) với n là số dòng. Vd: n = 4:
#
# 1.
# ```
#         *
#       * *
#     * * *
#   * * * *
# * * * * *
# ```
#
# ```
#    *      <-- for i in range(1,5): 1->4     (n-i)
#   **
#  ***
# ****
# ```
#
# 2.
# ```
#       *
#     * *
#   * * *
# * * * * * * * *
#         * * *
#         * *
#         *
# ```
#
# 3. (Optional) Tam giác giống ở giữa
# ```
# *
# * *
# *   *
# * * * * * * * *
#           *   *
#             * *
#               *
# ```

# %%
n = 4
for i in range(1,5):
    print((n-i+1)*'  ', (i+1)*' *', f" ({i})")

# %%
A=int(input('Enter a number: '))
#Hinh 1
print("Hinh 1")
for i in range (1,A+1):
    print('* '*i)

#Hinh 2
print("Hinh 2")
for i in range (1,A+1):
    print('* '*(A+1-i),'  '*(i-1))

#Hinh 3
print("Hinh 3")
for i in range (1,A+1):
    print('  '*(i-1),'* '*(A+1-i))

#Hinh 4
print("Hinh 4")
for i in range (1,A+1):
    print('  '*(A-i),'* '*i)

#Hinh 5
print("Hinh 5")
for i in range (1,A+1):
    print('  '*(A-i),'* '*(2*i-1),'  '*(A-i))

#Hinh 6
print('Hinh 6')
for i in range (1,A+1):
    print('* '*A)

#Hinh 7
print('Hinh 7')
for i in range(1,A+1):
    if i==1:
        print('* '*A)
    elif i in range(2,A):
        print('* ', '  ' * (A - 3), '*')
    else:
        print('* ' * A)

# %%
#Hinh 8
print('Hinh 8')
for i in range(1,A+1):
    if i in range(1,3):
        print('* ' * i)
    elif i in range(3,A):
        print('* ', '  ' * (i - 3), '*')
    else:
        print('* ' * A)

#Hinh 9
print('Hinh 9')
for i in range (A,0,-1):
    if i==A:
        print('* ' * A)
    elif i in range(A-1,2,-1):
        print('* ', '  ' * (i - 3), '*')
    else:
        print('* ' * i)

#Hinh 10
print('Hinh 10')
for i in range(1,2*A):
    if i in range(1,A+1):
        print('* '*i)
    else:
        print('','  '*(i-A-1),'* '*(2*A-i))

#Hinh 11
print('Hinh 11')
for i in range(1,2*A):
    if i in range(1,3):
        print('* '*i)
    elif i in range(3,A+1):
        print('* ', '  ' * (i - 3), '* ')
    elif i in range(A+1,2*A-2):
        print('','  '*(i-A-1),'* ','  '*(2*A-i-3),'* ')
    else:
        print('','  '*(i-A-1),'* '*(2*A-i))

#Hinh 12
print('Hinh 12')
for i in range (1,A):
    print('* '*i)
for i in range (A,A+1):
    print('* '*(2*i-1))
for j in range(A-1,0,-1):
    print('','  '*(2*A-j-2),'* '*j)

#Hinh 13
print('Hinh 13')
for i in range (1,3):
    print('* '*i)
for i in range (3,A):
    print('* ','  '*(i-3),'* ')
for i in range (A,A+1):
    print('* '*(2*i-1))
for j in range(A-1,2,-1):
    print('','  '*(2*A-j-2),'* ', '  '*(j-3),'* ')
for j in range(2,0,-1):
    print('','  '*(2*A-j-2),'* '*j)

#Hinh 14
print('Hinh 14')
for i in range (1,A):
    print('','  '*(A-2),'* '*i)
for i in range (A,A+1):
    print('* '*(2*i-1))
for j in range(A-1,0,-1):
    print('* '*j)

# %% [markdown]
# ### Find Pair
# Cho list A chứa các số nguyên đã sắp xếp theo thứ tự tăng dần.
# A = [3, 6, 7, 9, 11, 12] và một số nguyên sum. Tìm tất cả các cặp số (a,b) trong mảng A có tổng bằng sum
# vd ở đây nếu sum = 18 thì hàm find_pair(A, sum) == [(7,11), (6,12)]. Nếu không có cặp số nào thỏa mãn thì trả ra list rỗng

# %%
# Cách 1: Dùng 2 vòng for.
# Độ phức tạp O(n^2) ---> Trong trường hợp xấu nhất thì phải duyệt qua n*(n-1)/2 phần tử các mảng
A = [3, 6, 7, 9, 11, 12]
def find_pair(A, sum):
    ans = []
    for i in range(len(A)-1):
        for j in range(i+1, len(A)):
            if A[i] + A[j] == sum:
                ans.append((A[i], A[j]))
    return ans
find_pair([3, 6, 7, 9, 11, 12], 18)

# %%
# Cách 2: Nhanh hơn O(n): Duyệt mảng 1 lần dùng 2 con trỏ i, j từ 2 đầu.
# Lưu ý: chỉ đúng nếu mảng đã sắp xếp
def find_pair(A, sum):
    i, j = 0, len(A)-1
    ans = []
    while i < j:
        s = A[i] + A[j]
        if s == sum:
            ans.append((A[i],A[j]))
            j -= 1
        elif s < sum:
            i += 1
        else:
            j -= 1
    return ans

find_pair([3, 6, 7, 9, 11, 12], 18)
